# %%
import cufflinks as cf
import plotly
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
start_date = '2006, 9, 1'
end_date = '2016, 9, 1'

# %%
# Bank of America
BAC = data.DataReader("BAC", 'yahoo', start_date, end_date)
# CitiGroup
C = data.DataReader("C", 'yahoo', start_date, end_date)
# Goldman Sachs
GS = data.DataReader("GS", 'yahoo', start_date, end_date)
# JPMorgan Chase
JPM = data.DataReader("JPM", 'yahoo', start_date, end_date)
# Morgan Stanley
MS = data.DataReader("MS", 'yahoo', start_date, end_date)
# Wells Fargo
WFC = data.DataReader("WFC", 'yahoo', start_date, end_date)

# %%
"""** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**"""
tickers = ['BAC','C','GS','JPM','MS','WFC']
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
"""** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. 
Also pay attention to what axis you concatenate on.**"""

bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], keys=tickers, axis=1)
bank_stocks
# Out:
#                   BAC                                                \
#                  High        Low       Open      Close       Volume
# Date
# 2006-08-31  51.900002  51.470001  51.820000  51.470001   10533100.0
# 2006-09-01  51.840000  51.299999  51.830002  51.660000    9775300.0
# 2006-09-05  51.889999  51.490002  51.619999  51.750000    8992800.0
# 2006-09-06  51.910000  51.419998  51.500000  51.650002   10342800.0
# 2006-09-07  51.869999  51.430000  51.639999  51.509998    9487400.0
# ...               ...        ...        ...        ...          ...
# 2016-08-26  15.900000  15.580000  15.610000  15.790000  126886300.0
# 2016-08-29  16.010000  15.780000  15.810000  15.840000  120144900.0
# 2016-08-30  16.230000  15.800000  15.840000  16.190001  121280600.0
# 2016-08-31  16.240000  15.880000  16.209999  16.139999  127664300.0
# 2016-09-01  16.150000  15.750000  16.150000  15.980000  128812600.0
#
# ...

# %%
"""** Set the column name levels **"""
bank_stocks.columns.names = ['Bank Ticker','Stock Info']
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-08-31   51.900002  51.470001  51.820000  51.470001  10533100.0
# 2006-09-01   51.840000  51.299999  51.830002  51.660000   9775300.0
# 2006-09-05   51.889999  51.490002  51.619999  51.750000   8992800.0
# 2006-09-06   51.910000  51.419998  51.500000  51.650002  10342800.0
# 2006-09-07   51.869999  51.430000  51.639999  51.509998   9487400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-08-31   38.316319  497.100006  492.600006  495.200012  493.500000  ...
# 2006-09-01   38.457771  497.100006  492.100006  497.000000  493.700012  ...
# 2006-09-05   38.524746  496.799988  491.200012  493.100006  494.200012  ...
# ...

# %%
"""** What is the max Close price for each bank's stock throughout the time period?**"""
bank_stocks.xs('Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
"""** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. 
returns are typically defined by:**

𝑟𝑡=𝑝𝑡−𝑝𝑡−1/𝑝𝑡−1=𝑝𝑡/𝑝𝑡−1−1
"""
returns = pd.DataFrame()

# %%
"""** We can use pandas pct_change() method on the Close column to create a column representing this return value. 
Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's 
it as a column in the returns DataFrame.**"""

for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()
    
returns
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-08-31         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-09-01    0.003691  0.000405   0.003296    0.001533   0.015808    0.002014
# 2006-09-05    0.001742  0.001013   0.014349    0.001531   0.008828    0.000287
# 2006-09-06   -0.001932 -0.005868  -0.004032    0.001747  -0.019579    0.006029
# 2006-09-07   -0.002711 -0.011805  -0.013938   -0.014821  -0.002118   -0.010559
# ...                ...       ...        ...         ...        ...         ...
# 2016-08-26    0.016742  0.008348   0.000422    0.002270   0.006135    0.002687
# 2016-08-29    0.003167  0.003184   0.005423    0.011024   0.008023    0.021645
# 2016-08-30    0.022096  0.013542   0.014982    0.008215   0.024833    0.021388
# 2016-08-31   -0.003088 -0.003340   0.000531    0.000000  -0.004038    0.003556
# 2016-09-01   -0.009913 -0.007960  -0.005606   -0.004296  -0.004679   -0.007283
#
# ...

# %%
"""** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**"""
sns.set_style('whitegrid')
sns.pairplot(returns)

# %%
"""
** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. 
You should notice that 4 of the banks share the same day for the worst drop, 
did anything significant happen that day?**
"""

returns.xs('Date',axis=1,level=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17496/1504699326.py in <module>
#       5 """
#       6
# ----> 7 returns.xs('Date',axis=1,level=0)
#       8
#       9
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3745         if level is not None:
#    3746             if not isinstance(labels, MultiIndex):
# -> 3747                 raise TypeError("Index must be a MultiIndex")
#    3748             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3749
#
# TypeError: Index must be a MultiIndex

# %%
"""** Take a look at the standard deviation of the returns, which stock would you classify as 
the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**"""
returns.std()

# %%
"""** Create a displot using seaborn of the 2015 returns for Morgan Stanley **"""

data = returns.loc['2015-01-01':'2015-12-31']['MS Return']
sns.displot(data,kde=True,bins=100)

# %%
"""** Create a displot using seaborn of the 2008 returns for CitiGroup **"""

data = returns.loc['2008-01-01':'2008-12-31']['C Return']
sns.displot(data,kde=True,bins=100,color='red')

# %%
bank_stocks
# Out:
# Bank Ticker        BAC                                                \
# Stock Info        High        Low       Open      Close       Volume
# Date
# 2006-08-31   51.900002  51.470001  51.820000  51.470001   10533100.0
# 2006-09-01   51.840000  51.299999  51.830002  51.660000    9775300.0
# 2006-09-05   51.889999  51.490002  51.619999  51.750000    8992800.0
# 2006-09-06   51.910000  51.419998  51.500000  51.650002   10342800.0
# 2006-09-07   51.869999  51.430000  51.639999  51.509998    9487400.0
# ...                ...        ...        ...        ...          ...
# 2016-08-26   15.900000  15.580000  15.610000  15.790000  126886300.0
# 2016-08-29   16.010000  15.780000  15.810000  15.840000  120144900.0
# 2016-08-30   16.230000  15.800000  15.840000  16.190001  121280600.0
# 2016-08-31   16.240000  15.880000  16.209999  16.139999  127664300.0
# 2016-09-01   16.150000  15.750000  16.150000  15.980000  128812600.0
#
# ...

# %%
"""** Create a line plot showing Close price for each bank for the entire index of time. 
(Hint: Try using a for loop, or use .xs to get a cross section of the data.)**"""

data = bank_stocks.xs('Close',axis=1,level='Stock Info')
data.iplot()
# Out:
# <div>                            <div id="b91e1a38-59fb-44ed-b4c8-4e757b7ac1b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
"""** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**"""

data = bank_stocks.loc['2008-01-01':'2008-12-31']['BAC']['Close']
data.iplot()
# Out:
# <div>                            <div id="254b145e-e819-461b-abdf-5117746d0fdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
"""** Create a heatmap of the correlation between the stocks Close Price.**"""
data = bank_stocks.xs('Close',axis=1,level='Stock Info').corr()
sns.heatmap(data,annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
"""** Optional: Use seaborn's clustermap to cluster the correlations together:**"""
data = bank_stocks.xs('Close',axis=1,level='Stock Info').corr()
sns.clustermap(data,annot=True)

# %%
"""** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**"""

data = bank_stocks.loc['2015-01-01':'2016-01-01']['BAC']
data.iplot(kind='candle')
# Out:
# <div>                            <div id="b3a17546-539d-4d4b-8108-adfb7df6056a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
